# %% [markdown]
# ### Scraping da carwow.com di auto cinesi ed europee

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
def get_model_urls(brand_url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    res = requests.get(brand_url, headers=headers)
    soup = BeautifulSoup(res.content, 'lxml')

    model_links = soup.select('.card-compact-review')

    full_urls = []
    for link in model_links:
        href = link.get('href')
        if href:
            if href.startswith('/'):
                full_url = 'https://www.carwow.co.uk' + href.split('?')[0]
            else:
                full_url = href.split('?')[0]
            full_urls.append(full_url)

    return list(set(full_urls))  # Rimuove duplicati

# %%
def scrape_model_page(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.content, 'lxml')

    title = soup.select_one('h1').get_text(strip=True)
    
    price_elem = soup.select_one('.price--no-wrap')
    if price_elem:
        price = price_elem.get_text(strip=True)
    else:
        summary_price_elem = soup.select_one('.summary-list__item dd')
        price = summary_price_elem.get_text(strip=True) if summary_price_elem else 'Not found'
        
    rating_elem = soup.select_one('.review-overview__wowscore .wowscore-pill')
    rating = rating_elem.get_text(strip=True) if rating_elem else 'Not found'
    
    review_elems = soup.select('#slice-zone-0 .content-block p')
    if not review_elems:
        review_elems = soup.select('#verdict p')
    review = " ".join([elem.get_text(separator=" ", strip=True) for elem in review_elems]) if review_elems else 'Not found'

    return {
        'url': url,
        'title': title,
        'price': price,
        'rating': rating,
        'review': review
    }

# %%
brand_url = [
    'https://www.carwow.co.uk/mg',
    'https://www.carwow.co.uk/omoda',
    'https://www.carwow.co.uk/volkswagen', 
    'https://www.carwow.co.uk/dacia', 
    'https://www.carwow.co.uk/fiat',
    'https://www.carwow.co.uk/renault',
    'https://www.carwow.co.uk/citroen',
    'https://www.carwow.co.uk/bmw',
    'https://www.carwow.co.uk/peugeot',
    'https://www.carwow.co.uk/byd',
    'https://www.carwow.co.uk/gwm',
    'https://www.carwow.co.uk/jaecoo',
    'https://www.carwow.co.uk/leapmotor',
    'https://www.carwow.co.uk/xpeng',
    
    ]

for i, brand in enumerate(brand_url):
    print(f"\nAnalyzing: {brand.split('/')[-1]}\nNumber: {i+1}/{len(brand_url)}")
    model_urls = get_model_urls(brand)

    for i, url in enumerate(model_urls):
        print(f"\nAnalyzing: {url.split('/')[-1]}\nNumber: {i+1}/{len(model_urls)}")
        data = scrape_model_page(url)
        not_found_fields = [k for k, v in data.items() if v == 'Not found']
        if not_found_fields:
            print(f"Fields not found: {not_found_fields}")

        # Memorizza i dati in una lista
        if 'all_data' not in locals():
            all_data = []
        all_data.append(data)
# Out:
# Analyzing: mg
# Number: 1/14
#
# Analyzing: mg3
# Number: 1/11
#
# Analyzing: hs
# Number: 2/11
#
# Analyzing: cyberster
# Number: 3/11
#
# Analyzing: 2018
# Number: 4/11
#
# Analyzing: mg-4
# Number: 5/11
#
# Analyzing: 4-xpower
# Number: 6/11
#
# Analyzing: 5
# Number: 7/11
#
# Analyzing: gs
# Number: 8/11
#
# Analyzing: s5-ev
# Number: 9/11
#
# Analyzing: zs
# Number: 10/11
#
# Analyzing: zs-ev
# Number: 11/11
#
# Analyzing: omoda
# Number: 2/14
#
# Analyzing: omoda-5
# Number: 1/3
#
# Analyzing: omoda-9
# Number: 2/3
# Fields not found: ['rating']
#
# Analyzing: omoda-e5
# Number: 3/3
#
# Analyzing: volkswagen
# Number: 3/14
#
# Analyzing: t-roc
# Number: 1/24
#
# Analyzing: polo-gti
# Number: 2/24
#
# Analyzing: golf
# Number: 3/24
#
# Analyzing: polo
# Number: 4/24
#
# Analyzing: multivan
# Number: 5/24
#
# Analyzing: id3
# Number: 6/24
#
# Analyzing: t-cross
# Number: 7/24
#
# Analyzing: tiguan
# Number: 8/24
#
# Analyzing: id7
# Number: 9/24
#
# Analyzing: t-roc-cabriolet
# Number: 10/24
#
# Analyzing: taigo
# Number: 11/24
#
# Analyzing: id5
# Number: 12/24
#
# Analyzing: touran
# Number: 13/24
#
# Analyzing: golf-gti
# Number: 14/24
#
# Analyzing: idbuzz
# Number: 15/24
#
# Analyzing: golf-r
# Number: 16/24
#
# Analyzing: id4
# Number: 17/24
#
# Analyzing: touareg
# Number: 18/24
#
# Analyzing: tayron
# Number: 19/24
#
# Analyzing: golf-gte
# Number: 20/24
# Fields not found: ['rating']
#
# Analyzing: id7-tourer
# Number: 21/24
#
# Analyzing: touareg-r
# Number: 22/24
#
# Analyzing: passat
# Number: 23/24
#
# Analyzing: t-roc-r
# Number: 24/24
#
# Analyzing: dacia
# Number: 4/14
#
# Analyzing: jogger
# Number: 1/8
#
# Analyzing: sandero-stepway
# Number: 2/8
#
# Analyzing: sandero
# Number: 3/8
#
# Analyzing: bigster
# Number: 4/8
#
# Analyzing: duster
# Number: 5/8
#
# Analyzing: spring
# Number: 6/8
# Fields not found: ['rating']
#
# Analyzing: logan-mcv
# Number: 7/8
#
# Analyzing: logan-mcv-stepway
# Number: 8/8
#
# Analyzing: fiat
# Number: 5/14
#
# Analyzing: tipo-station-wagon
# Number: 1/18
#
# Analyzing: 500
# Number: 2/18
#
# Analyzing: 500x
# Number: 3/18
#
# Analyzing: 500l
# Number: 4/18
#
# Analyzing: punto
# Number: 5/18
# Fields not found: ['rating', 'review']
#
# Analyzing: 500-convertible
# Number: 6/18
#
# Analyzing: panda
# Number: 7/18
#
# Analyzing: qubo
# Number: 8/18
# Fields not found: ['price']
#
# Analyzing: 500c
# Number: 9/18
#
# Analyzing: tipo
# Number: 10/18
#
# Analyzing: 600
# Number: 11/18
#
# Analyzing: 500l-mpw
# Number: 12/18
#
# Analyzing: 124-spider
# Number: 13/18
#
# Analyzing: 500-electric
# Number: 14/18
#
# Analyzing: 600e
# Number: 15/18
#
# Analyzing: 500x-dolcevita-hatchback
# Number: 16/18
#
# Analyzing: panda-4x4
# Number: 17/18
#
# Analyzing: panda-cross
# Number: 18/18
#
# Analyzing: renault
# Number: 6/14
#
# Analyzing: clio-renaultsport
# Number: 1/19
# Fields not found: ['rating', 'review']
#
# Analyzing: grand-scenic
# Number: 2/19
#
# Analyzing: megane-rs
# Number: 3/19
#
# Analyzing: rafale
# Number: 4/19
#
# Analyzing: koleos
# Number: 5/19
#
# Analyzing: scenic-e-tech
# Number: 6/19
#
# Analyzing: megane
# Number: 7/19
#
# Analyzing: captur
# Number: 8/19
#
# Analyzing: symbioz
# Number: 9/19
#
# Analyzing: clio
# Number: 10/19
#
# Analyzing: arkana
# Number: 11/19
#
# Analyzing: megane-sports-tourer
# Number: 12/19
#
# Analyzing: zoe
# Number: 13/19
#
# Analyzing: megane-etech-electric
# Number: 14/19
#
# Analyzing: kadjar
# Number: 15/19
#
# Analyzing: 5-e-tech
# Number: 16/19
#
# Analyzing: scenic
# Number: 17/19
#
# Analyzing: twingo
# Number: 18/19
#
# Analyzing: austral
# Number: 19/19
#
# Analyzing: citroen
# Number: 7/14
#
# Analyzing: e-c3
# Number: 1/23
#
# Analyzing: e-berlingo
# Number: 2/23
#
# Analyzing: e-c4
# Number: 3/23
#
# Analyzing: ami
# Number: 4/23
#
# Analyzing: c1-airscape
# Number: 5/23
#
# Analyzing: c4
# Number: 6/23
#
# Analyzing: c4-cactus
# Number: 7/23
#
# Analyzing: holidays-campervan
# Number: 8/23
# Fields not found: ['rating']
#
# Analyzing: c5-aircross
# Number: 9/23
#
# Analyzing: c3-origin
# Number: 10/23
#
# Analyzing: c4-spacetourer
# Number: 11/23
#
# Analyzing: c3-aircross
# Number: 12/23
#
# Analyzing: c1
# Number: 13/23
#
# Analyzing: c5-x
# Number: 14/23
#
# Analyzing: e-c3-aircross
# Number: 15/23
#
# Analyzing: c4-x
# Number: 16/23
#
# Analyzing: grand-c4-spacetourer
# Number: 17/23
#
# Analyzing: c3
# Number: 18/23
#
# Analyzing: spacetourer
# Number: 19/23
#
# Analyzing: c3-picasso
# Number: 20/23
#
# Analyzing: e-c4-x
# Number: 21/23
#
# Analyzing: berlingo
# Number: 22/23
#
# Analyzing: e-spacetourer
# Number: 23/23
# Fields not found: ['rating']
#
# Analyzing: bmw
# Number: 8/14
#
# Analyzing: x5
# Number: 1/62
#
# Analyzing: ix
# Number: 2/62
#
# Analyzing: 6-series-convertible
# Number: 3/62
# Fields not found: ['price']
#
# Analyzing: m240i
# Number: 4/62
#
# Analyzing: i5
# Number: 5/62
#
# Analyzing: x5m
# Number: 6/62
#
# Analyzing: m3-touring
# Number: 7/62
#
# Analyzing: 2-series-convertible
# Number: 8/62
#
# Analyzing: x2
# Number: 9/62
#
# Analyzing: xm
# Number: 10/62
#
# Analyzing: x1
# Number: 11/62
#
# Analyzing: 4-series-gran-coupe
# Number: 12/62
#
# Analyzing: x6-m-competition
# Number: 13/62
#
# Analyzing: 2-series-active-tourer
# Number: 14/62
#
# Analyzing: 5-series
# Number: 15/62
#
# Analyzing: 8-series
# Number: 16/62
#
# Analyzing: ix3
# Number: 17/62
#
# Analyzing: 4-series
# Number: 18/62
#
# Analyzing: i4
# Number: 19/62
#
# Analyzing: m4-coupe
# Number: 20/62
#
# Analyzing: m135i
# Number: 21/62
#
# Analyzing: 6-series-gran-coupe
# Number: 22/62
#
# Analyzing: 2-series-gran-tourer
# Number: 23/62
#
# Analyzing: m8
# Number: 24/62
#
# Analyzing: i8
# Number: 25/62
#
# Analyzing: ix1
# Number: 26/62
#
# Analyzing: 8-series-gran-coupe
# Number: 27/62
# Fields not found: ['rating']
#
# Analyzing: i7
# Number: 28/62
#
# Analyzing: m240i-convertible
# Number: 29/62
#
# Analyzing: m5
# Number: 30/62
#
# Analyzing: x6m
# Number: 31/62
# Fields not found: ['rating', 'review']
#
# Analyzing: 5-series-touring
# Number: 32/62
# Fields not found: ['rating']
#
# Analyzing: 3-series
# Number: 33/62
#
# Analyzing: 3-series-gran-turismo
# Number: 34/62
#
# Analyzing: m4-convertible
# Number: 35/62
#
# Analyzing: x7
# Number: 36/62
#
# Analyzing: m3
# Number: 37/62
#
# Analyzing: i3
# Number: 38/62
#
# Analyzing: 6-series-gt
# Number: 39/62
#
# Analyzing: m8-gran-coupe
# Number: 40/62
#
# Analyzing: z4
# Number: 41/62
#
# Analyzing: x3
# Number: 42/62
#
# Analyzing: 2-series-coupe
# Number: 43/62
#
# Analyzing: x4-m
# Number: 44/62
#
# Analyzing: 4-series-convertible
# Number: 45/62
#
# Analyzing: m6
# Number: 46/62
# Fields not found: ['rating', 'review']
#
# Analyzing: m8-convertible
# Number: 47/62
# Fields not found: ['rating']
#
# Analyzing: x3-m
# Number: 48/62
#
# Analyzing: i5-touring
# Number: 49/62
#
# Analyzing: 2-series-gran-coupe
# Number: 50/62
#
# Analyzing: i8-roadster
# Number: 51/62
#
# Analyzing: m2
# Number: 52/62
#
# Analyzing: 8-series-convertible
# Number: 53/62
#
# Analyzing: 7-series
# Number: 54/62
#
# Analyzing: m5-touring
# Number: 55/62
#
# Analyzing: x5-m-competition
# Number: 56/62
#
# Analyzing: 3-series-touring
# Number: 57/62
#
# Analyzing: x7-m60i
# Number: 58/62
#
# Analyzing: 1-series
# Number: 59/62
#
# Analyzing: ix2
# Number: 60/62
#
# Analyzing: x6
# Number: 61/62
#
# Analyzing: x4
# Number: 62/62
#
# Analyzing: peugeot
# Number: 9/14
#
# Analyzing: e-208
# Number: 1/26
#
# Analyzing: 508-sw
# Number: 2/26
#
# Analyzing: e-3008
# Number: 3/26
#
# Analyzing: 208
# Number: 4/26
#
# Analyzing: e-rifter
# Number: 5/26
#
# Analyzing: 408
# Number: 6/26
#
# Analyzing: 108
# Number: 7/26
#
# Analyzing: traveller
# Number: 8/26
#
# Analyzing: 108-top
# Number: 9/26
#
# Analyzing: e-308
# Number: 10/26
#
# Analyzing: 308-sw
# Number: 11/26
#
# Analyzing: e-308-sw
# Number: 12/26
#
# Analyzing: rifter
# Number: 13/26
#
# Analyzing: 508-pse
# Number: 14/26
#
# Analyzing: 508
# Number: 15/26
#
# Analyzing: e-2008
# Number: 16/26
#
# Analyzing: 308-gti
# Number: 17/26
#
# Analyzing: 308
# Number: 18/26
#
# Analyzing: e-5008
# Number: 19/26
#
# Analyzing: 3008
# Number: 20/26
#
# Analyzing: partner-tepee
# Number: 21/26
# Fields not found: ['rating', 'review']
#
# Analyzing: e-408
# Number: 22/26
# Fields not found: ['rating']
#
# Analyzing: 5008
# Number: 23/26
#
# Analyzing: 208-gti
# Number: 24/26
#
# Analyzing: e-traveller
# Number: 25/26
# Fields not found: ['rating']
#
# Analyzing: 2008
# Number: 26/26
#
# Analyzing: byd
# Number: 10/14
#
# Analyzing: sealion-7
# Number: 1/5
#
# Analyzing: seal-u
# Number: 2/5
#
# Analyzing: atto-3
# Number: 3/5
#
# Analyzing: seal
# Number: 4/5
#
# Analyzing: dolphin
# Number: 5/5
#
# Analyzing: gwm
# Number: 11/14
#
# Analyzing: ora-03
# Number: 1/2
#
# Analyzing: haval-jolion-pro
# Number: 2/2
# Fields not found: ['rating']
#
# Analyzing: jaecoo
# Number: 12/14
#
# Analyzing: 7
# Number: 1/1
#
# Analyzing: leapmotor
# Number: 13/14
#
# Analyzing: c10
# Number: 1/2
# Fields not found: ['rating']
#
# Analyzing: t03
# Number: 2/2
#
# Analyzing: xpeng
# Number: 14/14
#
# Analyzing: g6
# Number: 1/1

# %%
len(all_data)
# Out:
# 205

# %%
# Dopo il ciclo, crea un DataFrame e salva come CSV

df = pd.DataFrame(all_data)
df.to_csv('/home/guidojobinformatica/sviluppo/rossato_job/info/carwow_scraped_data.csv', index=False)
print("Dati salvati in carwow_scraped_data.csv")
# Out:
# Dati salvati in carwow_scraped_data.csv
